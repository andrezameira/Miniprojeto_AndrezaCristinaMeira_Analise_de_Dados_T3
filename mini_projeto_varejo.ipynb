# %% [markdown]
# ### Importando as bibliotecas que serão utilizadas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Criando um DataFrame a paritr do CSV

# %%
# Como o separador usado no arquivo não é o padrão que é a vírgula, se fez necessário usar o parâmetro SET
df_varejo = pd.read_csv("base_varejo.csv", sep=";", encoding="utf-8")

# %% [markdown]
# ### Verificando as primeiras linhas do DataFrame

# %%
df_varejo.head()
# Out:
#          DATA  CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID     PR_CAT  \
# 0  01/02/2019   1000    534         M      4       1      C     67    BEBIDAS
# 1  01/02/2019   1000    534         M      4       1      C     70    BEBIDAS
# 2  01/02/2019   1000    534         M      4       1      C    178    HIGIENE
# 3  01/02/2019   1000    534         M      4       1      C      4  ALIMENTOS
# 4  01/02/2019   1000    534         M      4       1      C    175    LIMPEZA
#
#                 PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0  REFRIGERANTE GUARANA          NaN          NaN          NaN          NaN
# 1   REFRIGERANTE OUTROS          NaN          NaN          NaN          NaN
# 2       LENCO UMEDECIDO          NaN          NaN          NaN          NaN
# 3               ABACAXI          NaN          NaN          NaN          NaN
# 4     LIMPADOR MULTIUSO          NaN          NaN          NaN          NaN

# %% [markdown]
# ### Mantendo apenas as colunas que não estão em branco

# %%
df_varejo = df_varejo.dropna(axis=1)
df_varejo
# Out:
#               DATA   CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID  \
# 0       01/02/2019    1000    534         M      4       1      C     67
# 1       01/02/2019    1000    534         M      4       1      C     70
# 2       01/02/2019    1000    534         M      4       1      C    178
# 3       01/02/2019    1000    534         M      4       1      C      4
# 4       01/02/2019    1000    534         M      4       1      C    175
# ...            ...     ...    ...       ...    ...     ...    ...    ...
# 829995  19/08/2022  919822    155         F      2       0      B    183
# 829996  19/08/2022  919822    155         F      2       0      B     56
# 829997  19/08/2022  919822    155         F      2       0      B    227
# 829998  19/08/2022  919822    155         F      2       0      B    214
# 829999  19/08/2022  919822    155         F      2       0      B     59
#
#            PR_CAT               PR_NOME
# 0         BEBIDAS  REFRIGERANTE GUARANA
# 1         BEBIDAS   REFRIGERANTE OUTROS
# 2         HIGIENE       LENCO UMEDECIDO
# 3       ALIMENTOS               ABACAXI
# 4         LIMPEZA     LIMPADOR MULTIUSO
# ...           ...                   ...
# 829995  ALIMENTOS               KETCHUP
# 829996  ALIMENTOS      QUEIJO MUSSARELA
# 829997  ALIMENTOS                 ARROZ
# 829998  ALIMENTOS                CEBOLA
# 829999  ALIMENTOS            SALGADINHO
#
# [830000 rows x 10 columns]

# %% [markdown]
# ### Ajustando o nome das colunas para uma melhor identificá-las

# %%
df_varejo.columns = ["Data", "nota_fiscal", "id_cliente", "sexo", "estado_civil", "qtd_filhos", "classe_social", "sku_produto", "categoria_produto", "nome_produto"]
df_varejo
# Out:
#               Data  nota_fiscal  id_cliente sexo  estado_civil  qtd_filhos  \
# 0       01/02/2019         1000         534    M             4           1
# 1       01/02/2019         1000         534    M             4           1
# 2       01/02/2019         1000         534    M             4           1
# 3       01/02/2019         1000         534    M             4           1
# 4       01/02/2019         1000         534    M             4           1
# ...            ...          ...         ...  ...           ...         ...
# 829995  19/08/2022       919822         155    F             2           0
# 829996  19/08/2022       919822         155    F             2           0
# 829997  19/08/2022       919822         155    F             2           0
# 829998  19/08/2022       919822         155    F             2           0
# 829999  19/08/2022       919822         155    F             2           0
#
#        classe_social  sku_produto categoria_produto          nome_produto
# 0                  C           67           BEBIDAS  REFRIGERANTE GUARANA
# 1                  C           70           BEBIDAS   REFRIGERANTE OUTROS
# 2                  C          178           HIGIENE       LENCO UMEDECIDO
# 3                  C            4         ALIMENTOS               ABACAXI
# 4                  C          175           LIMPEZA     LIMPADOR MULTIUSO
# ...              ...          ...               ...                   ...
# 829995             B          183         ALIMENTOS               KETCHUP
# 829996             B           56         ALIMENTOS      QUEIJO MUSSARELA
# 829997             B          227         ALIMENTOS                 ARROZ
# 829998             B          214         ALIMENTOS                CEBOLA
# 829999             B           59         ALIMENTOS            SALGADINHO
#
# [830000 rows x 10 columns]
